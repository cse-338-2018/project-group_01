# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### The first dataset

# %% [markdown]
# Load the data

# %%
data1 = pd.read_csv('/content/drive/MyDrive/AI Datasets/ML_papers.csv')
data1.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                         Name + autors  \
# 0                                                                TensorFlow%3A A system for large scale machine Abadi Barham/46200b99c40e8586c8a0f588488ab6414119fb28
# 1                                                        TensorFlow%3A Large Scale Machine Learning on Systems Abadi Agarwal/9c9d7247f8c51ec5a02b0d911d1d7b9e8160495d
# 2  Data Mining Practical Machine Learning Tools and %E0%B8%AA%E0%B8%B7%E0%B8%9A%E0%B8%AA%E0%B8%B4%E0%B8%87%E0%B8%AB%E0%B9%8C/b42b1bfdc262bf99e9484e2e9df94df216b96374
# 3                                                                        Machine learning a probabilistic perspective Murphy/25badc676197a70aaf9911865eb03469e402ba57
# ...

# %% [markdown]
# Checking which columns have null values

# %%
data1.isnull().any()
# Out:
# Unnamed: 0       False
# Name + autors    False
# Fields            True
# Date              True
# Abstract         False
# Citations         True
# PDF link          True
# dtype: bool

# %% [markdown]
# Dropping the columns with null values

# %%
data1.dropna(axis=1, inplace = True)
data1.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                                                                                         Name + autors  \
# 0                                                                TensorFlow%3A A system for large scale machine Abadi Barham/46200b99c40e8586c8a0f588488ab6414119fb28
# 1                                                        TensorFlow%3A Large Scale Machine Learning on Systems Abadi Agarwal/9c9d7247f8c51ec5a02b0d911d1d7b9e8160495d
# 2  Data Mining Practical Machine Learning Tools and %E0%B8%AA%E0%B8%B7%E0%B8%9A%E0%B8%AA%E0%B8%B4%E0%B8%87%E0%B8%AB%E0%B9%8C/b42b1bfdc262bf99e9484e2e9df94df216b96374
# 3                                                                        Machine learning a probabilistic perspective Murphy/25badc676197a70aaf9911865eb03469e402ba57
# ...

# %%
data1.iloc[10]['Abstract']
# Out:
# 'We show that certain choices for the nature of the GP, such as the type of kernel and the treatment of its hyperparameters, can play a crucial role in obtaining a good optimizer.   '

# %% [markdown]
# Making sure the dataset doesn't contain any missing value

# %%
data1.isnull().any()
# Out:
# Unnamed: 0       False
# Name + autors    False
# Abstract         False
# dtype: bool

# %%
data1.shape
# Out:
# (946, 3)

# %% [markdown]
# Dropping unnecessary columns

# %%
data1.drop(['Unnamed: 0','Name + autors'],axis=1,inplace = True)
data1.shape
# Out:
# (946, 1)

# %% [markdown]
# Renaming the column so that the dataset can be combined with other datasets

# %%
data1.rename(columns = {'Abstract':'abstract'}, inplace = True)

# %%
data1.head()
# Out:
#                                                                                                                                                                                                                                                   abstract
# 0                                                                                                                                                  TensorFlow is a machine learning system that operates at large scale and in heterogeneous environments.
# 1                                                                                          This paper describes the TensorFlow interface for expressing machine learning algorithms, and an implementation of that interface that we have built at Google.
# 2
# ...

# %%
data1.iloc[90]['abstract']
# Out:
# 'Imbalanced-learn is an open-source python toolbox aiming at providing a wide range of methods to cope with the problem of imbalanced dataset frequently encountered in machine learning .'

# %% [markdown]
# ### Second Dataset

# %%
data2 = pd.read_csv('/content/drive/MyDrive/AI Datasets/ai_papers.csv')
data2.head()
# Out:
#                                                                                                                    title  \
# 0                                                                        MetaFormer is Actually What You Need for Vision
# 1                                                                         Turbo Autoencoder with a Trainable Interleaver
# 2  Ab-initio calculation of point defect equilibria during heat treatment: Nitrogen, hydrogen, and silicon doped diamond
# 3     Divergent electrostriction at ferroelectric phase transitions: example of strain-induced ferroelectiricty in KTaO3
# 4                                                  ProxyFL: Decentralized Federated Learning through Proxy Model Sharing
#
# ...

# %%
data2.isnull().any()
# Out:
# title        False
# abstract     False
# published    False
# authors      False
# url          False
# dtype: bool

# %%
data2.shape
# Out:
# (8000, 5)

# %%
data2.drop(['published','url','title','authors'],axis=1,inplace = True)
data2.shape
# Out:
# (8000, 1)

# %%
data2.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ### Third Dataset

# %%
df3 = pd.read_csv('/content/drive/MyDrive/AI Datasets/Train.csv')
df3.head()
# Out:
#      id  \
# 0  1824
# 1  3094
# 2  8463
# 3  2082
# 4  8687
#
# ...

# %%
df3.isnull().any()
# Out:
# id                                              False
# ABSTRACT                                        False
# Computer Science                                False
# Mathematics                                     False
# Physics                                         False
# Statistics                                      False
# Analysis of PDEs                                False
# Applications                                    False
# Artificial Intelligence                         False
# Astrophysics of Galaxies                        False
# Computation and Language                        False
# Computer Vision and Pattern Recognition         False
# Cosmology and Nongalactic Astrophysics          False
# Data Structures and Algorithms                  False
# Differential Geometry                           False
# Earth and Planetary Astrophysics                False
# Fluid Dynamics                                  False
# ...

# %%
df3.shape
# Out:
# (14004, 31)

# %%
#d3 = df3[df3['Computer Science']==1]
#d3.head()
# Out:
#        id                                           ABSTRACT  \
# 1    3094  we propose the framework considering optimal $...
# 4    8687  deep neural perception and control networks ar...
# 5    2342  analyzing job hopping behavior was important c...
# 8   18709  nowadays data compressors are applied to many ...
# 10   3084  we study a problem of extracting the selective...
#
#     Computer Science  Mathematics  Physics  Statistics  Analysis of PDEs  \
# 1                  1            0        0           0                 0
# 4                  1            0        0           0                 0
# 5                  1            0        0           0                 0
# 8                  1            1        0           1                 0
# 10                 1            0        0           0                 0
#
#     Applications  Artificial Intelligence  Astrophysics of Galaxies  ...  \
# 1              0                        0                         0  ...
# ...

# %%
#d3.shape

# %%
data3 = df3[['ABSTRACT']]
data3.shape
# Out:
# (14004, 1)

# %%
data3.rename(columns = {'ABSTRACT':'abstract'}, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data3.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ### Fourth Dataset

# %%
df4 = pd.read_csv('/content/drive/MyDrive/AI Datasets/mixed.csv')
df4.head()
# Out:
#    ID  \
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5
#
#                                                                                                                                             TITLE  \
# 0                                                                                                     Reconstructing Subject-Specific Effect Maps
# 1                                                                                                              Rotation Invariance Neural Network
# 2                                                                          Spherical polyharmonics and Poisson kernels for polyharmonic functions
# 3                                                     A finite element approximation for the stochastic Maxwell--Landau--Lifshitz--Gilbert system
# 4  Comparative study of Discrete Wavelet Transforms and Wavelet Tensor Train decomposition to feature extraction of FTIR data of medicinal plants
#
# ...

# %%
df4.shape
# Out:
# (20972, 9)

# %%
d4 = df4[df4['Computer Science']==1]
d4.head()
# Out:
#     ID  \
# 0    1
# 1    2
# 4    5
# 10  11
# 13  14
#
#                                                                                                                                              TITLE  \
# 0                                                                                                      Reconstructing Subject-Specific Effect Maps
# 1                                                                                                               Rotation Invariance Neural Network
# 4   Comparative study of Discrete Wavelet Transforms and Wavelet Tensor Train decomposition to feature extraction of FTIR data of medicinal plants
# 10                                             A global sensitivity analysis and reduced order models for hydraulically-fractured horizontal wells
# 13                                                                                                                On Varieties of Ordered Automata
#
# ...

# %%
d4.shape
# Out:
# (8594, 9)

# %%
d4.isnull().any()
# Out:
# ID                      False
# TITLE                   False
# ABSTRACT                False
# Computer Science        False
# Physics                 False
# Mathematics             False
# Statistics              False
# Quantitative Biology    False
# Quantitative Finance    False
# dtype: bool

# %%
data4 = d4[['ABSTRACT']]
data4.shape
# Out:
# (8594, 1)

# %%
data4.rename(columns = {'ABSTRACT':'abstract'}, inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data4.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ### The fifth dataset

# %%
dc = pd.read_csv('/content/drive/MyDrive/AI Datasets/covid.csv')
dc.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                                                                                               title  \
# 0  Clinical features of culture-proven Mycoplasma pneumoniae infections at King Abdulaziz University Hospital, Jeddah, Saudi Arabia
# ...

# %%
dc.shape
# Out:
# (1056660, 19)

# %%
dc.isnull().any()
# Out:
# cord_uid            False
# sha                  True
# source_x            False
# title                True
# doi                  True
# pmcid                True
# pubmed_id            True
# license             False
# abstract             True
# publish_time         True
# authors              True
# journal              True
# mag_id               True
# who_covidence_id     True
# arxiv_id             True
# pdf_json_files       True
# pmc_json_files       True
# url                  True
# s2_id                True
# dtype: bool

# %%
df5 = dc[['abstract']]
df5.shape
# Out:
# (1056660, 1)

# %%
df5.dropna(axis=0, inplace = True)
df5.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# ...

# %%
df5.shape
# Out:
# (821118, 1)

# %%
data5 = df5.head(10000)
data5.shape
# Out:
# (10000, 1)

# %%
data5.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ### The sixth dataset

# %%
df6 = pd.read_csv('/content/drive/MyDrive/AI Datasets/cord19_df.csv')
df6.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0                                  paper_id  \
# 0           0  3cdc48bb9e40afd30a59463b7872761a726998c8
# 1           1  d99acb4e99be7852aa61a688c9fbd38d44b5a252
# 2           2  748d4c57fe1acc8d9d97cf574f7dea5296f9386c
# 3           3  b891efc6e1419713b05ff7d89b26d260478c28df
# 4           4  353852971069ad5794445e5c1ab6077ce23da75d
#
# ...

# %%
df6.shape
# Out:
# (47110, 17)

# %%
df6.isnull().any()
# Out:
# Unnamed: 0      False
# paper_id        False
# body_text       False
# methods          True
# results          True
# source           True
# title            True
# doi              True
# abstract         True
# publish_time     True
# authors          True
# journal          True
# arxiv_id         True
# url              True
# publish_year    False
# is_covid19      False
# study_design    False
# dtype: bool

# %%
d6 = df6[['abstract']]

# %%
d6.dropna(axis=0, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
d6.isnull().any()
# Out:
# abstract    False
# dtype: bool

# %%
d6.shape
# Out:
# (41062, 1)

# %%
data6 = d6.head(10000)
data6.shape
# Out:
# (10000, 1)

# %%
data6.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ### Combining all the data

# %%
concate_data = pd.concat([data2,data3,data4,data5,data6])
concate_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
concate_data.shape
# Out:
# (50598, 1)

# %%
concate_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11339    False
# 11340    False
# 11341     True
# 11342    False
# 11343    False
# Length: 50598, dtype: bool

# %%
concate_data.drop_duplicates(keep='first', inplace=True)

# %%
concate_data.shape
# Out:
# (49801, 1)

# %%
concate_data.to_csv('/content/drive/MyDrive/AI Datasets/combined.csv')

# %% [markdown]
# ### Displaying the combined data

# %%
df = pd.read_csv('/content/drive/MyDrive/AI Datasets/combined.csv')
df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
# ...

# %%
df.iloc[100]['abstract']
# Out:
# 'In this paper, we propose a network coding (NC) based approach to\nultra-reliable low-latency communication (URLLC) over erasure channels. In\ntransmitting multiple data packets, we demonstrate that the use of random NC\ncan improve the reliability in terms of decoding error probability, while it\nincurs a longer decoding delay than a well-known K-repetition. To avoid a long\ndecoding delay, we consider a sliding NC (SNC) design that allows a highly\nreliable transmission of each data packet with a guaranteed decoding delay. A\nfew design examples are derived and their decoding error rates are analyzed.\nThrough the analysis, we can show that the decoding error rate of SNC is much\nlower than that of K-repetition at the same spectral efficiency, which means a\nmore reliable transmission can be achieved using SNC than K-repetition.'

# %% [markdown]
# Renaming the 'Unnamed: 0' column into 'id'

# %%
df.rename(columns = {'Unnamed: 0':'id'}, inplace = True)
df.head()
# Out:
#    id                                           abstract
# 0   0  TensorFlow is a machine learning system that o...
# 1   1  This paper describes the TensorFlow interface ...
# 2   2
# 3   3  A comprehensive and self-contained introductio...
# 4   4  Scikit-learn is a Python module integrating a ...

# %%
df.isnull().any()
# Out:
# id          False
# abstract    False
# dtype: bool
